-- %%
data LivingOrganism a = Human String | Pet String | Plant String

-- %%
data Show a => Error a = LexerError {errorMessage :: a} 
           | ParserError {errorMessage :: a} 
           | TypeError {errorMessage :: a}
           | CCompilerError {errorMessage :: a}
           deriving (Eq)
-- Making `errorMessage` of type `String` for now; could be changed later to parametatized type concstuctors 
-- for different types of error message


{-
data ErrorMessage = String 
data Error = LexerError ErrorMessage | ParserError ErrorMessage | TypeError ErrorMessage deriving (Show, Eq)
-}

instance Show Error where
    show (LexerError errorMessage) = "Lexer Error: \n" ++ errorMessage ++ "\n"
    show (ParserError errorMessage) = "Parser Error: \n" ++ errorMessage ++ "\n"
    show (TypeError errorMessage) = "Type Error: \n" ++  errorMessage ++ "\n"
    show (CCompilerError errorMessage) = "GCC Error: \n" ++ errorMessage ++ "\n"

printError :: Error -> IO ()
printError x = putStr $ show x
-- Out:
-- <interactive>:1:6: error: Illegal datatype context (use DatatypeContexts): Show a =>

-- %%
data StageName = Lexer
               | Parser
               | TypeChecker
               | GCC
               
data Stage input output = Stage {stageName :: StageName,
                                 runStage :: input -> StageErrorOrOutput output
                                 } 
                          

data StageErrorOrOutput output = Right {stageOutput :: output }
                               | Left {stageError :: Error}


runStage :: Stage input output -> (input -> StageErrorOrOutput output)
runStage (Stage stageType stageRunner) = stageRunner
-- Out:
-- Line 19: Avoid lambda
-- Found:
-- (\ input -> Right input)
-- Why not:
-- Right

-- %%
data Day' = Saturday 
     | Sunday
    | Monday
    deriving Show

data Day = Day Day' String deriving Show

printDay :: Day -> IO ()
printDay (Day day message) = (putStr.show) day

-- %%
-- Out:
-- <interactive>:4:1: error:
--     Multiple declarations of ‘add’
--     Declared at: <interactive>:2:1
--                  <interactive>:4:1
-- <interactive>:3:1: error:
--     Duplicate type signatures for ‘add’
--     at <interactive>:1:1-3
--        <interactive>:3:1-3

-- %%
:type otherwise
-- Out:
-- otherwise :: Bool

-- %%
data Error a = Error a

data ErrorType = ErrorType
-- Out:
-- Line 1: Use newtype instead of data
-- Found:
-- data Type a = Error a
-- Why not:
-- newtype Type a = Error a

-- %%
:type undefined
-- Out:
-- undefined :: forall {a}. a

-- %%
show undefined
-- Out:
-- Prelude.undefined
-- CallStack (from HasCallStack):
--   error, called at libraries/base/GHC/Err.hs:75:14 in base:GHC.Err
--   undefined, called at <interactive>:1:6 in interactive:Ghci208

-- %%
show _|_
-- Out:
-- Parse error (line 1, column 9): parse error (possibly incorrect indentation or mismatched brackets)
